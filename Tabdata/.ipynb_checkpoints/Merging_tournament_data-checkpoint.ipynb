# %%
import pandas as pd
import numpy as np
import os

# %%
# List only files in the current directory
files = [f for f in os.listdir('.') if os.path.isfile(f)]

for f in files:
    print(f)
    
txt_files = [f for f in files if f.lower().endswith('.txt')]

print(txt_files)
# Out:
# 14th IIT Bombay Debate 2022 (23 rms).txt
# 14th IIT Bombay Debate 2022 (23 rms)_rounds_done.xlsx
# 14th IIT Bombay Debate 2022 (23 rms)_speakertab_done.xlsx
# 14th IIT Bombay Debate 2022 (23 rms)_teamtab_done.xlsx
# 15th IIT Bombay Debate 2023 (23 rms).txt
# 15th IIT Bombay Debate 2023 (23 rms)_rounds_done.xlsx
# 15th IIT Bombay Debate 2023 (23 rms)_speakertab_done.xlsx
# 15th IIT Bombay Debate 2023 (23 rms)_teamtab_done.xlsx
# Africa IV 2022 (21 rms).txt
# Africa IV 2022 (21 rms)_rounds_done.xlsx
# Africa IV 2022 (21 rms)_speakertab_done.xlsx
# Africa IV 2022 (21 rms)_teamtab_done.xlsx
# All_Debates.xlsx
# AODC BP 2022 (28 rms).txt
# AODC BP 2022 (28 rms)_rounds_done.xlsx
# AODC BP 2022 (28 rms)_speakertab_done.xlsx
# AODC BP 2022 (28 rms)_teamtab_done.xlsx
# Bulacan IV 2023 (23 rms).txt
# Bulacan IV 2023 (23 rms)_rounds_done.xlsx
# Bulacan IV 2023 (23 rms)_speakertab_done.xlsx
# Bulacan IV 2023 (23 rms)_teamtab_done.xlsx
# CEBVAM.txt
# CEBVAM_rounds_done.xlsx
# CEBVAM_speakertab_done.xlsx
# CEBVAM_teamtab_done.xlsx
# Diliman Debate Open 2023 (35 rms).txt
# Diliman Debate Open 2023 (35 rms)_rounds_done.xlsx
# Diliman Debate Open 2023 (35 rms)_speakertab_done.xlsx
# Diliman Debate Open 2023 (35 rms)_teamtab_done.xlsx
# Doxbridge Pre-WUDC (44 rms).txt
# Doxbridge Pre-WUDC (44 rms)_rounds_done.xlsx
# Doxbridge Pre-WUDC (44 rms)_speakertab_done.xlsx
# Doxbridge Pre-WUDC (44 rms)_teamtab_done.xlsx
# Eristic BPD (25 rms).txt
# Eristic BPD (25 rms)_rounds_done.xlsx
# Eristic BPD (25 rms)_speakertab_done.xlsx
# Eristic BPD (25 rms)_teamtab_done.xlsx
# Hart House Intervasity 2024 (25rms).txt
# Hart House Intervasity 2024 (25rms)_rounds_done.xlsx
# Hart House Intervasity 2024 (25rms)_speakertab_done.xlsx
# Hart House Intervasity 2024 (25rms)_teamtab_done.xlsx
# Hong Kong Debating Championship 2024 (21 rms).txt
# Hong Kong Debating Championship 2024 (21 rms)_rounds_done.xlsx
# Hong Kong Debating Championship 2024 (21 rms)_speakertab_done.xlsx
# Hong Kong Debating Championship 2024 (21 rms)_teamtab_done.xlsx
# ILNU BPD 2023 (23 rms).txt
# Ilocos Norte IV 2022 (32 rms).txt
# India WUDC Fundraiser (22 rms).txt
# Johns Hopkins Open 2022 (22 rms).txt
# Kampala open 3.0 (25 rms).txt
# Kampala open 3.0 (25 rms)_rounds_done.xlsx
# Kampala open 3.0 (25 rms)_speakertab_done.xlsx
# Kampala open 3.0 (25 rms)_teamtab_done.xlsx
# Kumasi Debate Open 2024 (21 rms).txt
# LSE Open 2022 (20 rms).txt
# LSE Open 2024 (20 rooms).txt
# Macau Debate Open 2025(23 rms).txt
# Macau Debate Open 2025(23 rms)_rounds_done.xlsx
# Macau Debate Open 2025(23 rms)_speakertab_done.xlsx
# Macau Debate Open 2025(23 rms)_teamtab_done.xlsx
# Malaysia Online Debate Open 2025（25 rms）.txt
# Malaysia Online Debate Open 2025（25 rms）_rounds_done.xlsx
# Malaysia Online Debate Open 2025（25 rms）_speakertab_done.xlsx
# Malaysia Online Debate Open 2025（25 rms）_teamtab_done.xlsx
# Manzar 2023 (28 rms).txt
# McGill IV 2024 (21 rms).txt
# Osaka IV 2024 (21 rms).txt
# Oxford IV 2022.txt
# Oxford IV 2023 (32 rms).txt
# Oxford IV 2024 (28 rms).txt
# Oxford IV 2024 (28 rms)_rounds_done.xlsx
# Oxford IV 2024 (28 rms)_speakertab_done.xlsx
# Oxford IV 2024 (28 rms)_teamtab_done.xlsx
# Philippine National Debate Championship Diliman (27 rms).txt
# Princeton IV 2023 (39 rms).txt
# Princeton IV 2024 (32 rms).txt
# Princeton IV 2024 (32 rms)_rounds_done.xlsx
# Princeton IV 2024 (32 rms)_speakertab_done.xlsx
# Princeton IV 2024 (32 rms)_teamtab_done.xlsx
# Princeton2025_rounds_done.xlsx
# Princeton2025_speakertab_done.xlsx
# Princeton2025_teamtab_done.xlsx
# Ramadan Debate Open (20 rms).txt
# RMLBPD Pre-WUDC 2023 (21 rms).txt
# RPDA Pre-PAUDC Debating Competiton 2023 (30 rms).txt
# Santa Mesa Debate Open 2024 (34 rms).txt
# Scrape_tab_to_txt.ipynb
# Shanghai International Debate Open (38 rms).txt
# Shanghai International Debate Open 2025(38 rms).txt
# Shanghai International Debate Open 2025(38 rms)_rounds_done.xlsx
# Shanghai International Debate Open 2025(38 rms)_speakertab_done.xlsx
# Shanghai International Debate Open 2025(38 rms)_teamtab_done.xlsx
# Shri Ram Pre ABP (20 rms).txt
# Shri Ram Pre ABP (20 rms)_rounds_done.xlsx
# Shri Ram Pre ABP (20 rms)_speakertab_done.xlsx
# Shri Ram Pre ABP (20 rms)_teamtab_done.xlsx
# SIDO 2023 (23 rms).txt
# SMDO 2024 (35 rooms).txt
# Sofia Online Open 2024 (23 rms).txt
# Sofia Online Open 2024 Part 2 (34 rms).txt
# St Andrew's Pre-EUDC 2025.txt
# St Andrew's Pre-EUDC 2025_rounds_done.xlsx
# St Andrew's Pre-EUDC 2025_speakertab_done.xlsx
# St Andrew's Pre-EUDC 2025_teamtab_done.xlsx
# St Andrews Pre-EUDC Competition (20 rms).txt
# St Andrews Pre-EUDC Competition (20 rms)_rounds_done.xlsx
# St Andrews Pre-EUDC Competition (20 rms)_speakertab_done.xlsx
# St Andrews Pre-EUDC Competition (20 rms)_teamtab_done.xlsx
# Sunway Debate Open 2023 (22 rms).txt
# Tab2Database.ipynb
# Tab2Database2.ipynb
# Tab2Database3.ipynb
# The Delhi Debate 2024 (21 rms).txt
# The Delhi Debate 2024 (21 rms)_rounds_done.xlsx
# The Delhi Debate 2024 (21 rms)_speakertab_done.xlsx
# The Delhi Debate 2024 (21 rms)_teamtab_done.xlsx
# Tokyo IV 2023 (23 rms).txt
# Tournament_masterlist.xlsx
# Trinity IV 2022 (21 rms).txt
# Uhuru Worlds 2022.txt
# Uhuru Worlds 2023 (63 rms).txt
# Uhuru Worlds 2024.txt
# Uhuru Worlds 2025 (83 rms).txt
# Uhuru Worlds 2025 (83 rms)_rounds_done.xlsx
# Uhuru Worlds 2025 (83 rms)_speakertab_done.xlsx
# Uhuru Worlds 2025 (83 rms)_teamtab_done.xlsx
# Untitled.ipynb
# Vienna IV 2022 (22 rms).txt
# Vienna IV 2023 (22 rms).txt
# Vienna IV 2024 (22 rms).txt
# Vienna IV 2025 (22rms).txt
# Vienna IV 2025 (22rms)_rounds_done.xlsx
# Vienna IV 2025 (22rms)_speakertab_done.xlsx
# Vienna IV 2025 (22rms)_teamtab_done.xlsx
# Vienna Online Open Pre-EUDC 2024 (27 rms).txt
# Vienna Online Open Pre-EUDC 2024 (27 rms)_rounds_done.xlsx
# Vienna Online Open Pre-EUDC 2024 (27 rms)_speakertab_done.xlsx
# Vienna Online Open Pre-EUDC 2024 (27 rms)_teamtab_done.xlsx
# Vienna Online Open Pre-WUDC 2024 (32rms).txt
# Vienna Online Open Pre-WUDC 2024 (32rms)_rounds_done.xlsx
# Vienna Online Open Pre-WUDC 2024 (32rms)_speakertab_done.xlsx
# Vienna Online Open Pre-WUDC 2024 (32rms)_teamtab_done.xlsx
# Vienna Pre-WUDC 2022 (28 rms).txt
# Warwick Pre-EUDC 2025 (29 rms).txt
# Warwick Pre-EUDC 2025 (29 rms)_rounds_done.xlsx
# Warwick Pre-EUDC 2025 (29 rms)_speakertab_done.xlsx
# Warwick Pre-EUDC 2025 (29 rms)_teamtab_done.xlsx
# Western IV 2022 (23 rms).txt
# Western IV 2023.txt
# Yale IV 2022.txt
# Yale IV 2023 (25 rms).txt
# ~$Tournament_masterlist.xlsx
# ['14th IIT Bombay Debate 2022 (23 rms).txt', '15th IIT Bombay Debate 2023 (23 rms).txt', 'Africa IV 2022 (21 rms).txt', 'AODC BP 2022 (28 rms).txt', 'Bulacan IV 2023 (23 rms).txt', 'CEBVAM.txt', 'Diliman Debate Open 2023 (35 rms).txt', 'Doxbridge Pre-WUDC (44 rms).txt', 'Eristic BPD (25 rms).txt', 'Hart House Intervasity 2024 (25rms).txt', 'Hong Kong Debating Championship 2024 (21 rms).txt', 'ILNU BPD 2023 (23 rms).txt', 'Ilocos Norte IV 2022 (32 rms).txt', 'India WUDC Fundraiser (22 rms).txt', 'Johns Hopkins Open 2022 (22 rms).txt', 'Kampala open 3.0 (25 rms).txt', 'Kumasi Debate Open 2024 (21 rms).txt', 'LSE Open 2022 (20 rms).txt', 'LSE Open 2024 (20 rooms).txt', 'Macau Debate Open 2025(23 rms).txt', 'Malaysia Online Debate Open 2025（25 rms）.txt', 'Manzar 2023 (28 rms).txt', 'McGill IV 2024 (21 rms).txt', 'Osaka IV 2024 (21 rms).txt', 'Oxford IV 2022.txt', 'Oxford IV 2023 (32 rms).txt', 'Oxford IV 2024 (28 rms).txt', 'Philippine National Debate Championship Diliman (27 rms).txt', 'Princeton IV 2023 (39 rms).txt', 'Princeton IV 2024 (32 rms).txt', 'Ramadan Debate Open (20 rms).txt', 'RMLBPD Pre-WUDC 2023 (21 rms).txt', 'RPDA Pre-PAUDC Debating Competiton 2023 (30 rms).txt', 'Santa Mesa Debate Open 2024 (34 rms).txt', 'Shanghai International Debate Open (38 rms).txt', 'Shanghai International Debate Open 2025(38 rms).txt', 'Shri Ram Pre ABP (20 rms).txt', 'SIDO 2023 (23 rms).txt', 'SMDO 2024 (35 rooms).txt', 'Sofia Online Open 2024 (23 rms).txt', 'Sofia Online Open 2024 Part 2 (34 rms).txt', "St Andrew's Pre-EUDC 2025.txt", 'St Andrews Pre-EUDC Competition (20 rms).txt', 'Sunway Debate Open 2023 (22 rms).txt', 'The Delhi Debate 2024 (21 rms).txt', 'Tokyo IV 2023 (23 rms).txt', 'Trinity IV 2022 (21 rms).txt', 'Uhuru Worlds 2022.txt', 'Uhuru Worlds 2023 (63 rms).txt', 'Uhuru Worlds 2024.txt', 'Uhuru Worlds 2025 (83 rms).txt', 'Vienna IV 2022 (22 rms).txt', 'Vienna IV 2023 (22 rms).txt', 'Vienna IV 2024 (22 rms).txt', 'Vienna IV 2025 (22rms).txt', 'Vienna Online Open Pre-EUDC 2024 (27 rms).txt', 'Vienna Online Open Pre-WUDC 2024 (32rms).txt', 'Vienna Pre-WUDC 2022 (28 rms).txt', 'Warwick Pre-EUDC 2025 (29 rms).txt', 'Western IV 2022 (23 rms).txt', 'Western IV 2023.txt', 'Yale IV 2022.txt', 'Yale IV 2023 (25 rms).txt']

# %%
def open_excel_comp(txt_file):
    comp_name = txt_file[:-4]
    print(comp_name)
    df = pd.read_excel(comp_name+"_rounds_done.xlsx")
    print(len(df))
    return df, comp_name

data = pd.DataFrame()


for i in range(len(txt_files)):
    df, comp_name = open_excel_comp(txt_files[i])
    data = pd.concat([df, data], ignore_index=True)
# Out:
# 14th IIT Bombay Debate 2022 (23 rms)
# 123
# 15th IIT Bombay Debate 2023 (23 rms)
# 124
# Africa IV 2022 (21 rms)
# 115
# AODC BP 2022 (28 rms)
# 184
# Bulacan IV 2023 (23 rms)
# 102
# CEBVAM
# 125
# Diliman Debate Open 2023 (35 rms)
# 184
# Doxbridge Pre-WUDC (44 rms)
# 246
# Eristic BPD (25 rms)
# 128
# Hart House Intervasity 2024 (25rms)
# 135
# Hong Kong Debating Championship 2024 (21 rms)
# 115
# ILNU BPD 2023 (23 rms)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 12
#       8 data = pd.DataFrame()
#      11 for i in range(len(txt_files)):
# ---> 12     df, comp_name = open_excel_comp(txt_files[i])
#      13     data = pd.concat([df, data], ignore_index=True)
#
# Cell In[3], line 4, in open_excel_comp(txt_file)
#       2 comp_name = txt_file[:-4]
#       3 print(comp_name)
# ----> 4 df = pd.read_excel(comp_name+"_rounds_done.xlsx")
#       5 print(len(df))
#       6 return df, comp_name
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ILNU BPD 2023 (23 rms)_rounds_done.xlsx'

# %%
data.to_excel("All_Debates.xlsx", index=False)  # index=False removes the row index
