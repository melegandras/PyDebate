# %% [markdown]
# I want to have

# %%
import pandas as pd
import numpy as np
import os

# %%
# List only files in the current directory
files = [f for f in os.listdir('.') if os.path.isfile(f)]

for f in files:
    print(f)
    
txt_files = [f for f in files if f.lower().endswith('.txt')]

print(txt_files)
# Out:
# Cambridge IV 2024 (22 rooms).txt
# Eristic BPD (25 rms).txt
# Hart House Intervasity 2024 (25rms).txt
# Kampala open 3.0 (25 rms).txt
# Kumasi Debate Open 2024 (21 rms).txt
# Macau Debate Open 2025(23 rms).txt
# Malaysia Online Debate Open 2025（25 rms）.txt
# Osaka IV 2024 (21 rms).txt
# Oxford IV 2024 (28 rms).txt
# Princeton IV 2024 (32 rms).txt
# Scrape_tab_to_txt.ipynb
# Shanghai International Debate Open 2025(38 rms).txt
# Shri Ram Pre ABP (20 rms).txt
# St Andrew's Pre-EUDC 2025.txt
# St Andrews Pre-EUDC Competition (20 rms).txt
# Tab2Database.ipynb
# Tab2Database2.ipynb
# The Delhi Debate 2024 (21 rms).txt
# Tournament_masterlist.xlsx
# Uhuru Worlds 2025 (83 rms).txt
# Vienna IV 2025 (22rms).txt
# Vienna Online Open Pre-EUDC 2024 (27 rms).txt
# Vienna Online Open Pre-WUDC 2024 (32rms).txt
# Warwick Pre-EUDC 2025 (29 rms).txt
# Warwick Pre-EUDC 2025 (29 rms)_rounds_done.xlsx
# Warwick Pre-EUDC 2025 (29 rms)_speakertab_done.xlsx
# Warwick Pre-EUDC 2025 (29 rms)_teamtab_done.xlsx
# ['Cambridge IV 2024 (22 rooms).txt', 'Eristic BPD (25 rms).txt', 'Hart House Intervasity 2024 (25rms).txt', 'Kampala open 3.0 (25 rms).txt', 'Kumasi Debate Open 2024 (21 rms).txt', 'Macau Debate Open 2025(23 rms).txt', 'Malaysia Online Debate Open 2025（25 rms）.txt', 'Osaka IV 2024 (21 rms).txt', 'Oxford IV 2024 (28 rms).txt', 'Princeton IV 2024 (32 rms).txt', 'Shanghai International Debate Open 2025(38 rms).txt', 'Shri Ram Pre ABP (20 rms).txt', "St Andrew's Pre-EUDC 2025.txt", 'St Andrews Pre-EUDC Competition (20 rms).txt', 'The Delhi Debate 2024 (21 rms).txt', 'Uhuru Worlds 2025 (83 rms).txt', 'Vienna IV 2025 (22rms).txt', 'Vienna Online Open Pre-EUDC 2024 (27 rms).txt', 'Vienna Online Open Pre-WUDC 2024 (32rms).txt', 'Warwick Pre-EUDC 2025 (29 rms).txt']

# %% [markdown]
# # Start: Goal
# ##### Debate Project
# The goal of this project is to use programming to enhance the level of competitive academic debating, mostly by doing advanced data-analysis and further techniques.
#
# ##### Tabdata
# A huge chapter in this is the creation of a comprehensive debate database, that includes all elements of debating that can be used to measure, evaluate, and increase performance. At this junction of the project the **TabData** project tries to set up the database of debates and some follow-up metrics, such as "elo-score".
#
# ##### Tabdata useage
# In ideal case this can be used for predicting winners of debates, predicting and analyzing biases and outliers with motions, judges, speaker-scores of certain judges, hardships with motion-types, correlations between outcomes in debate tournaments, or just providing an overview about the long-term trends within debating by having a comprehensive data through a long cross-section of time.
#
# # About the data
# Our data arrives in a csv. <span style="color:red">**At this test programme, it is manually downloaded**</span>  but for future tournament databases, it will be downloaded by scraping with Selenium.
#
# The data consists the outcomes of debate tournaments. This has 3 main sections.
#
# #### Team tab ####
# The teamtab consists the teams that participated at the tournament, and the ranking between the teams at the end of the tournament's preliminary rounds. As a rule of thumb, tournaments run for 5 rounds, but major tournaments such as European or World Championships have 9 preliminary rounds. The top teams go through to the elimination rounds, to reach, and eventually win the finals. Teams that do not reach the playoffs, are ranked by their respective positions in the tab.
#
# For example, if there are 40 teams in a tournament, the top 8 will go to the semi-finals, with a preset seeding in British Parliamentary debates where in Semi-Final-1 the 1st, 4th, 5th, and 8th seeded teams debate, and in Semi-Final-2 the 2nd, 3rd, 6th, 7th seeded teams debate. Each semi-final will have 2 teams that advance to the finals. So, despite teams do not carry the resulst to the outrounds, they have an impact on each team's result. Teams 9-40 are ranked based on their positions within the tab.
#
# #### Speaker tab ####
# In the same csv, following the teamtab, comes the speakertab. While the teamtab is ranking teams, the speakertab ranks the individual speakers within a debate tournaments. Because in British Parliamentary debating the speaker score of the individual speakers within a debate is summed, and teams are ranked in the order of the sum of these scores, teamtab and speakertab strongly correlates, but they don't have to be the same. Furthermore, it provides further ways to analyse data for us. Both the teamtab and the spakertab is with their own headers within the data, therefore slicing up the csv to teamtab and speakertab is not particularly complex.
#
# #### Debate results ####
# The third, and largest part of the csv consists each team's result within a given debate, and also the role they had (f.e. Opening Government) and the adjucating judges too. Each row consists the data for each individual team's separate round.
#
# Each round was obtained separately and attached to the csv, so every round has its own headers, that is needed, because the data does not consist the roundnumbers themselves.
#
# The data looks something like this:
# | team              | result | side    | adjudicators  |
# | :---------------- | :------: | ----: | --------------|
# | Team1        |  1st   | Opening Government | Judge1,Judge2 |
# | Team2           |  1st   | Opening Government | Judge3 |
# | Team3    |  2nd   | Closing Opposition |  Judge4,Judge6 |
# | Team4 |  4th   | Opening Opposition | Judge3 |
#
# From the data we can see that Team 2 and Team 4 debated in the same debate at the given round, because they had the same adjudicators. (Judge 3). *Team2* finished 2nd, and *Team4* finished 4th. This itself is not new information, because we could retrieve this information from the teamtab. However, the teamtab provides no information on the opponents, and the speaker scores the team have received.
#
#
# #### The task ####
# The teamtab, the speakertab, and the debate_results dataframes are connected by 1 common column: the team's names. Each tournament, each team has its unique name. However, it is possible for John Blue to run in the team "Blue Brothers" in 1 tournament, with his sibling Adam Blue, and run with a different teamname at a following tournament, with a different teammate, or the very same. Therefore, the hardest part once the database is created is to clear out the database from people with similar names. Fortunately, most of the times debaters have unique names. As a matter of fact, the teamtab is not even needed for the creation of the "debate-level" dataframe.
#
# So, for each row of debate results, we are first going to retrieve the speaker scores and the speakers for the team from the speakertab. Then we will group the 4 debating teams together to one row. And finally, we will separate each adjudicator to a different row. This will give us 1 row of data in our phenomenal database.

# %% [markdown]
# ## Start: Read in data ##

# %%
def get_comp_name(txt_file):
    comp_name = txt_file[:-4]
    print(comp_name)
    df = pd.read_csv(txt_file, delimiter ='\t', on_bad_lines='warn')
    print(len(df))
    return df, comp_name

data = pd.DataFrame()

for i in range(len(txt_files)):
    df, comp_name = get_comp_name(txt_files[i])
df
# Out:
# Cambridge IV 2024 (22 rooms)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 11
#       8 data = pd.DataFrame()
#      10 for i in range(len(txt_files)):
# ---> 11     df, comp_name = get_comp_name(txt_files[i])
#      12 df
#
# Cell In[69], line 4, in get_comp_name(txt_file)
#       2 comp_name = txt_file[:-4]
#       3 print(comp_name)
# ----> 4 df = pd.read_csv(txt_file, delimiter ='\t', on_bad_lines='warn')
#       5 print(len(df))
#       6 return df, comp_name
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Cambridge IV 2024 (22 rooms).txt'

# %%
df[200:300]
# Out:
#        Rk                   team   categories  \
# 200   75=              Myra Kong          ESL
# 201   75=  Max Gasslitter Strobl          ESL
# 202   75=            cal birtley          NaN
# 203   75=          Na’ama Benamy          ESL
# 204   75=   Jake O&#x27;Loughlin          NaN
# ..    ...                    ...          ...
# 295  166=         Jonathan Krapp          ESL
# 296  166=              Eric Peng       Novice
# 297  173=        Krishaan Doctor  ESL, Novice
# 298  173=   Paulina Šalkauskaitė       Novice
# 299  173=          Athang Shinde          ESL
#
#                                          R1  R2  R3  R4  R5 Pts  Spk   1sts  \
# 200      We debate best in grocery store ai  77  79  78  81  72  387  77.40
# 201        DM Spiritual Slut and German Dad  76  81  76  77  77  387  77.40
# 202      Aberdeen BW… (B)ut not the one you  78  78  77  77  77  387  77.40
# 203          KU Mandatory military dropouts  80  77  78  72  80  387  77.40
# 204  UCD L&amp;H E(veryone else was unavail  78  78  76  76  79  387  77.40
# ..                                      ...  ..  ..  ..  ..  ..  ...    ...
# 295                           DAV Aachen YJ  78  73  74  73  76  374  74.80
# 296                please i just want to go  75  74  74  75  76  374  74.80
# 297                          SoBo Crusaders  72  76  72  77  75  372  74.40
# 298       are we picking a team name or are  75  75  74  74  74  372  74.40
# 299      Cooper House - Perseverance in Per  76  76  71  75  74  372  74.40
#
#      2nds
# 200  3.01
# 201  1.85
# 202  0.49
# 203  2.94
# 204  1.20
# ..    ...
# 295  1.94
# 296  0.75
# 297  2.06
# 298  0.49
# 299  1.85
#
# [100 rows x 12 columns]

# %% [markdown]
# ## I. Teamtab ##
# First, we need to create the teamtab

# %%
# Find the index of the row with the known value
stop_index = df[df['Rk'] == 'Rk'].index[0]

# %%
stop_index
# Out:
# 124

# %%
teamtab = df.iloc[:stop_index]
teamtab
# Out:
#        Rk                                    team categories   R1   R2   R3  \
# 0       1  LSE When did Aniket get so big and str        NaN  1st  2nd  1st
# 1       2      The ideal of a platonic relationsh        NaN  1st  1st  1st
# 2       3                      ANU Guangzhou Mama        NaN  1st  2nd  1st
# 3       4                             Cambridge B        NaN  1st  1st  3rd
# 4       5  KCL It’s not clocking to you that I am        NaN  1st  1st  4th
# ..    ...                                     ...        ...  ...  ...  ...
# 119   120                                 SWING 5        NaN    —    —    —
# 120  121=                        AU Taanish Arora        ESL    —    —    —
# 121  121=                                   UWI A        NaN    —    —    —
# 122  121=                         Becky and Adika        ESL    —    —    —
# 123  121=                                   UTJ B        NaN    —    —    —
#
#       R4   R5 Pts  Spk 1sts 2nds
# 0    1st  2nd  13  810    3    2
# 1    3rd  1st  13  804    4    0
# 2    2nd  1st  13  802    3    2
# 3    2nd  1st  12  809    3    1
# 4    1st  1st  12  801    4    0
# ..   ...  ...  ..  ...  ...  ...
# 119  4th    —   0  133    0    0
# 120    —    —   —    —    0    0
# 121    —    —   —    —    0    0
# 122    —    —   —    —    0    0
# 123    —    —   —    —    0    0
#
# [124 rows x 12 columns]

# %%
#Remove useless data
target_column = 'Spk'
column_index = teamtab.columns.get_loc(target_column)

# Slice the DataFrame to keep columns up to and including the target column
teamtab = teamtab.iloc[:, :column_index + 1]
teamtab
# Out:
#        Rk                                    team categories   R1   R2   R3  \
# 0       1  LSE When did Aniket get so big and str        NaN  1st  2nd  1st
# 1       2      The ideal of a platonic relationsh        NaN  1st  1st  1st
# 2       3                      ANU Guangzhou Mama        NaN  1st  2nd  1st
# 3       4                             Cambridge B        NaN  1st  1st  3rd
# 4       5  KCL It’s not clocking to you that I am        NaN  1st  1st  4th
# ..    ...                                     ...        ...  ...  ...  ...
# 119   120                                 SWING 5        NaN    —    —    —
# 120  121=                        AU Taanish Arora        ESL    —    —    —
# 121  121=                                   UWI A        NaN    —    —    —
# 122  121=                         Becky and Adika        ESL    —    —    —
# 123  121=                                   UTJ B        NaN    —    —    —
#
#       R4   R5 Pts  Spk
# 0    1st  2nd  13  810
# 1    3rd  1st  13  804
# 2    2nd  1st  13  802
# 3    2nd  1st  12  809
# 4    1st  1st  12  801
# ..   ...  ...  ..  ...
# 119  4th    —   0  133
# 120    —    —   —    —
# 121    —    —   —    —
# 122    —    —   —    —
# 123    —    —   —    —
#
# [124 rows x 10 columns]

# %%
df2 = df.drop(teamtab.index)
df2.reset_index(drop=True, inplace=True)
df2
# Out:
#                                                Rk                   team  \
# 0                                              Rk                   name
# 1                                               1  Shaurya Chandravanshi
# 2                                              2=      Fraser McConachie
# 3                                              2=         Sachin Tissera
# 4                                              2=          Arjun Gunalan
# ..                                            ...                    ...
# 886                                          team                 result
# 887       UWODS Revealed Preference for Suffering              advancing
# 888            GUU (C)an you spot the difference?             eliminated
# 889                      DU raam bharose aaye hai             eliminated
# 890  Aberdeen Don&#x27;t ask us about the balkans             eliminated
#
#              categories                                                 R1  \
# 0              category                                               team
# 1                   NaN                 The ideal of a platonic relationsh
# 2                   NaN                                        Cambridge B
# 3                   ESL             LSE When did Aniket get so big and str
# 4                   NaN             LSE When did Aniket get so big and str
# ..                  ...                                                ...
# 886                side                                       adjudicators
# 887  Opening Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 888  Opening Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 889  Closing Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 890  Closing Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#       R2   R3   R4   R5  Pts    Spk   1sts   2nds
# 0     R1   R2   R3   R4   R5  Total    Avg  Stdev
# 1     80   82   83   82   82    409  81.80   0.98
# 2     81   81   79   81   83    405  81.00   1.26
# 3     80   80   81   84   80    405  81.00   1.55
# 4     80   81   81   83   80    405  81.00   1.10
# ..   ...  ...  ...  ...  ...    ...    ...    ...
# 886  NaN  NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 887  NaN  NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 888  NaN  NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 889  NaN  NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 890  NaN  NaN  NaN  NaN  NaN    NaN    NaN    NaN
#
# [891 rows x 12 columns]

# %% [markdown]
# ## II. The speaker tab

# %%
stop_index2 = df2[df2['Rk'] == 'team'].index[0]
speakertab = df2.iloc[:stop_index2]

#remove top row & reset index:
speakertab = speakertab.iloc[1:].reset_index(drop=True)
speakertab
# Out:
#        Rk                   team categories  \
# 0       1  Shaurya Chandravanshi        NaN
# 1      2=      Fraser McConachie        NaN
# 2      2=         Sachin Tissera        ESL
# 3      2=          Arjun Gunalan        NaN
# 4      5=          Olivia Arbour        NaN
# ..    ...                    ...        ...
# 241  233=              Speaker 2        NaN
# 242  233=              Speaker 2        NaN
# 243  233=              Speaker 2        NaN
# 244  233=              Speaker 2        NaN
# 245  233=              Speaker 2        NaN
#
#                                          R1  R2  R3  R4  R5 Pts  Spk   1sts  \
# 0        The ideal of a platonic relationsh  80  82  83  82  82  409  81.80
# 1                               Cambridge B  81  81  79  81  83  405  81.00
# 2    LSE When did Aniket get so big and str  80  80  81  84  80  405  81.00
# 3    LSE When did Aniket get so big and str  80  81  81  83  80  405  81.00
# 4                               Cambridge B  81  81  80  80  82  404  80.80
# ..                                      ...  ..  ..  ..  ..  ..  ...    ...
# 241                                 swing 1   —   —   —   —   —    —      —
# 242                                 swing 2   —   —   —   —   —    —      —
# 243                                 swing 3   —   —   —   —   —    —      —
# 244                                 SWING 4   —   —   —   —   —    —      —
# 245                                 SWING 5   —   —   —   —   —    —      —
#
#      2nds
# 0    0.98
# 1    1.26
# 2    1.55
# 3    1.10
# 4    0.75
# ..    ...
# 241     —
# 242     —
# 243     —
# 244     —
# 245     —
#
# [246 rows x 12 columns]

# %%
#Remove useless data
target_column = 'Spk'
column_index = speakertab.columns.get_loc(target_column)

# Slice the DataFrame to keep columns up to and including the target column
speakertab = speakertab.iloc[:, :column_index + 1]
speakertab
# Out:
#        Rk                   team categories  \
# 0       1  Shaurya Chandravanshi        NaN
# 1      2=      Fraser McConachie        NaN
# 2      2=         Sachin Tissera        ESL
# 3      2=          Arjun Gunalan        NaN
# 4      5=          Olivia Arbour        NaN
# ..    ...                    ...        ...
# 241  233=              Speaker 2        NaN
# 242  233=              Speaker 2        NaN
# 243  233=              Speaker 2        NaN
# 244  233=              Speaker 2        NaN
# 245  233=              Speaker 2        NaN
#
#                                          R1  R2  R3  R4  R5 Pts  Spk
# 0        The ideal of a platonic relationsh  80  82  83  82  82  409
# 1                               Cambridge B  81  81  79  81  83  405
# 2    LSE When did Aniket get so big and str  80  80  81  84  80  405
# 3    LSE When did Aniket get so big and str  80  81  81  83  80  405
# 4                               Cambridge B  81  81  80  80  82  404
# ..                                      ...  ..  ..  ..  ..  ..  ...
# 241                                 swing 1   —   —   —   —   —    —
# 242                                 swing 2   —   —   —   —   —    —
# 243                                 swing 3   —   —   —   —   —    —
# 244                                 SWING 4   —   —   —   —   —    —
# 245                                 SWING 5   —   —   —   —   —    —
#
# [246 rows x 10 columns]

# %%
speakertab = speakertab.rename(columns={'Rk': 'SpeakRank','team':'speaker','R1':'team'})
speakertab
# Out:
#     SpeakRank                speaker categories  \
# 0           1  Shaurya Chandravanshi        NaN
# 1          2=      Fraser McConachie        NaN
# 2          2=         Sachin Tissera        ESL
# 3          2=          Arjun Gunalan        NaN
# 4          5=          Olivia Arbour        NaN
# ..        ...                    ...        ...
# 241      233=              Speaker 2        NaN
# 242      233=              Speaker 2        NaN
# 243      233=              Speaker 2        NaN
# 244      233=              Speaker 2        NaN
# 245      233=              Speaker 2        NaN
#
#                                        team  R2  R3  R4  R5 Pts  Spk
# 0        The ideal of a platonic relationsh  80  82  83  82  82  409
# 1                               Cambridge B  81  81  79  81  83  405
# 2    LSE When did Aniket get so big and str  80  80  81  84  80  405
# 3    LSE When did Aniket get so big and str  80  81  81  83  80  405
# 4                               Cambridge B  81  81  80  80  82  404
# ..                                      ...  ..  ..  ..  ..  ..  ...
# 241                                 swing 1   —   —   —   —   —    —
# 242                                 swing 2   —   —   —   —   —    —
# 243                                 swing 3   —   —   —   —   —    —
# 244                                 SWING 4   —   —   —   —   —    —
# 245                                 SWING 5   —   —   —   —   —    —
#
# [246 rows x 10 columns]

# %%
# Get the first 4 and last column names
first_columns = speakertab.columns[:4].tolist()
last_column = speakertab.columns[-1]

# Get the middle columns that need renaming
#These will be the round results
middle_columns = speakertab.columns[4:-1]

# Create new names for the middle columns (e.g., 'NewCol1', 'NewCol2', ...)
new_middle_columns = [f'R{i}' for i in range(1, len(middle_columns) + 1)]

# Combine the first columns, renamed middle columns, and last column
new_columns = first_columns + new_middle_columns + [last_column]

# Apply the new column names to the DataFrame
speakertab.columns = new_columns

speakertab
# Out:
#     SpeakRank                speaker categories  \
# 0           1  Shaurya Chandravanshi        NaN
# 1          2=      Fraser McConachie        NaN
# 2          2=         Sachin Tissera        ESL
# 3          2=          Arjun Gunalan        NaN
# 4          5=          Olivia Arbour        NaN
# ..        ...                    ...        ...
# 241      233=              Speaker 2        NaN
# 242      233=              Speaker 2        NaN
# 243      233=              Speaker 2        NaN
# 244      233=              Speaker 2        NaN
# 245      233=              Speaker 2        NaN
#
#                                        team  R1  R2  R3  R4  R5  Spk
# 0        The ideal of a platonic relationsh  80  82  83  82  82  409
# 1                               Cambridge B  81  81  79  81  83  405
# 2    LSE When did Aniket get so big and str  80  80  81  84  80  405
# 3    LSE When did Aniket get so big and str  80  81  81  83  80  405
# 4                               Cambridge B  81  81  80  80  82  404
# ..                                      ...  ..  ..  ..  ..  ..  ...
# 241                                 swing 1   —   —   —   —   —    —
# 242                                 swing 2   —   —   —   —   —    —
# 243                                 swing 3   —   —   —   —   —    —
# 244                                 SWING 4   —   —   —   —   —    —
# 245                                 SWING 5   —   —   —   —   —    —
#
# [246 rows x 10 columns]

# %% [markdown]
# ## III. Connecting the speakertab & Debate Results

# %%
df3 = df2.drop(speakertab.index)
df3 = df3.iloc[1:].reset_index(drop=True)
df3.reset_index(drop=True, inplace=True)
df3
# Out:
#                                                Rk        team  \
# 0                                            team      result
# 1                                           LSE C         2nd
# 2          LSE When did Aniket get so big and str         1st
# 3                                  SoBo Crusaders         4th
# 4              4 am start :smile: 3 am start :cry         3rd
# ..                                            ...         ...
# 639                                          team      result
# 640       UWODS Revealed Preference for Suffering   advancing
# 641            GUU (C)an you spot the difference?  eliminated
# 642                      DU raam bharose aaye hai  eliminated
# 643  Aberdeen Don&#x27;t ask us about the balkans  eliminated
#
#              categories                                                 R1  \
# 0                  side                                             ballot
# 1    Opening Government                                        View Ballot
# 2    Opening Opposition                                        View Ballot
# 3    Closing Government                                        View Ballot
# 4    Closing Opposition                                        View Ballot
# ..                  ...                                                ...
# 639                side                                       adjudicators
# 640  Opening Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 641  Opening Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 642  Closing Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 643  Closing Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#                                      R2   R3   R4   R5  Pts  Spk 1sts 2nds
# 0                          adjudicators  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    Maša PopeskovićⒸ , Matheus Furtado  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    Maša PopeskovićⒸ , Matheus Furtado  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    Maša PopeskovićⒸ , Matheus Furtado  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4    Maša PopeskovićⒸ , Matheus Furtado  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..                                  ...  ...  ...  ...  ...  ...  ...  ...
# 639                                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 640                                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 641                                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 642                                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 643                                 NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [644 rows x 12 columns]

# %%
df3.loc[df3['R1'] == 'View Ballot', 'R1'] = df3['R2']
df3 = df3.iloc[:,:4]
df3["Round"] = 0
df3
# Out:
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\1722710906.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["Round"] = 0
#                                                Rk        team  \
# 0                                            team      result
# 1                                           LSE C         2nd
# 2          LSE When did Aniket get so big and str         1st
# 3                                  SoBo Crusaders         4th
# 4              4 am start :smile: 3 am start :cry         3rd
# ..                                            ...         ...
# 639                                          team      result
# 640       UWODS Revealed Preference for Suffering   advancing
# 641            GUU (C)an you spot the difference?  eliminated
# 642                      DU raam bharose aaye hai  eliminated
# 643  Aberdeen Don&#x27;t ask us about the balkans  eliminated
#
#              categories                                                 R1  \
# 0                  side                                             ballot
# 1    Opening Government                 Maša PopeskovićⒸ , Matheus Furtado
# 2    Opening Opposition                 Maša PopeskovićⒸ , Matheus Furtado
# 3    Closing Government                 Maša PopeskovićⒸ , Matheus Furtado
# 4    Closing Opposition                 Maša PopeskovićⒸ , Matheus Furtado
# ..                  ...                                                ...
# 639                side                                       adjudicators
# 640  Opening Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 641  Opening Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 642  Closing Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 643  Closing Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#      Round
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 639      0
# 640      0
# 641      0
# 642      0
# 643      0
#
# [644 rows x 5 columns]

# %%
round_counter = 0
row_numbers = df3.index[df3["Rk"] == "team"].tolist()

#Trick "dumbass": In order for the next for loop to iterate through, I append a 0 to the end of my list. 
#This is needed, so when the loop is at the last round of the we don't end up with referring to a roundnumber, that would be 
#Larger than the last element in the list. 
#What I mean: check a few lines down
row_numbers.append(0)
print(row_numbers)


df4 = df3
for i in df4.index:
    if row_numbers[round_counter] == i:
        print(i)
        print(round_counter)
        
        #Trick "dumbass" --> in the last round if I did not append a 0, row_umbers[round_counter] would be
        #larger than the last element's position in the row_numbers list
        #But things just work perfectly this way, like a shitty spagetthi
        round_counter += 1
    df4.loc[i, "Round"] = round_counter  # Example logic
row_numbers = row_numbers[:-1]
df4
# Out:
# [0, 117, 234, 351, 468, 577, 594, 611, 620, 625, 634, 639, 0]
# 0
# 0
# 117
# 1
# 234
# 2
# 351
# 3
# 468
# 4
# 577
# 5
# 594
# 6
# 611
# 7
# 620
# 8
# 625
# 9
# 634
# 10
# 639
# 11
#                                                Rk        team  \
# 0                                            team      result
# 1                                           LSE C         2nd
# 2          LSE When did Aniket get so big and str         1st
# 3                                  SoBo Crusaders         4th
# 4              4 am start :smile: 3 am start :cry         3rd
# ..                                            ...         ...
# 639                                          team      result
# 640       UWODS Revealed Preference for Suffering   advancing
# 641            GUU (C)an you spot the difference?  eliminated
# 642                      DU raam bharose aaye hai  eliminated
# 643  Aberdeen Don&#x27;t ask us about the balkans  eliminated
#
#              categories                                                 R1  \
# 0                  side                                             ballot
# 1    Opening Government                 Maša PopeskovićⒸ , Matheus Furtado
# 2    Opening Opposition                 Maša PopeskovićⒸ , Matheus Furtado
# 3    Closing Government                 Maša PopeskovićⒸ , Matheus Furtado
# 4    Closing Opposition                 Maša PopeskovićⒸ , Matheus Furtado
# ..                  ...                                                ...
# 639                side                                       adjudicators
# 640  Opening Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 641  Opening Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 642  Closing Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 643  Closing Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#      Round
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 639     12
# 640     12
# 641     12
# 642     12
# 643     12
#
# [644 rows x 5 columns]

# %%
df4.head(20)
# Out:
#                                             Rk    team          categories  \
# 0                                         team  result                side
# 1                                        LSE C     2nd  Opening Government
# 2       LSE When did Aniket get so big and str     1st  Opening Opposition
# 3                               SoBo Crusaders     4th  Closing Government
# 4           4 am start :smile: 3 am start :cry     3rd  Closing Opposition
# 5                              Kimbhut Kimakar     4th  Opening Government
# 6               KU Mandatory military dropouts     2nd  Opening Opposition
# 7   Warwick This House Would Break (But Not Up     3rd  Closing Government
# 8           Why does Hilary have an Australian     1st  Closing Opposition
# 9                       surely we will wake up     2nd  Opening Government
# 10                      More boobs than brains     1st  Opening Opposition
# 11                    DU raam bharose aaye hai     3rd  Closing Government
# 12                    Ito Atsuki Fan Club 😘💕❤️     4th  Closing Opposition
# 13                           Woodstock Reserve     4th  Opening Government
# 14                                 Cambridge B     1st  Opening Opposition
# 15                  he’s got me by the marbles     3rd  Closing Government
# 16           IITB Chakraborty &amp; Raghav Raj     2nd  Closing Opposition
# 17                                       MCU A     4th  Opening Government
# 18       Zhu-ko &amp; Hum-iroh take on Ba Sing     1st  Opening Opposition
# 19      Ethos, pathos... what&#x27;s the third     2nd  Closing Government
#
#                                                    R1  Round
# 0                                              ballot      1
# 1                  Maša PopeskovićⒸ , Matheus Furtado      1
# 2                  Maša PopeskovićⒸ , Matheus Furtado      1
# 3                  Maša PopeskovićⒸ , Matheus Furtado      1
# 4                  Maša PopeskovićⒸ , Matheus Furtado      1
# 5   Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...      1
# 6   Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...      1
# 7   Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...      1
# 8   Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...      1
# 9                         ilijaⒸ , Ngo Nguyen Minh Tu      1
# 10                        ilijaⒸ , Ngo Nguyen Minh Tu      1
# 11                        ilijaⒸ , Ngo Nguyen Minh Tu      1
# 12                        ilijaⒸ , Ngo Nguyen Minh Tu      1
# 13     Pjotr KosterⒸ , Aaryav Bansal , Advika SharmaⓉ      1
# 14     Pjotr KosterⒸ , Aaryav Bansal , Advika SharmaⓉ      1
# 15     Pjotr KosterⒸ , Aaryav Bansal , Advika SharmaⓉ      1
# 16     Pjotr KosterⒸ , Aaryav Bansal , Advika SharmaⓉ      1
# 17            Krishaang KohliⒸ , Ellen Roper , Wajeeh      1
# 18            Krishaang KohliⒸ , Ellen Roper , Wajeeh      1
# 19            Krishaang KohliⒸ , Ellen Roper , Wajeeh      1

# %%
df4.tail(20)
# Out:
#                                                Rk        team  \
# 624                                   Cambridge B  eliminated
# 625                                          team      result
# 626                                   Potsdam A-Z   advancing
# 627             Djorđa Kratovca 65/8 parking spot   advancing
# 628                        DKW Vienna (A)mbulance  eliminated
# 629                                  UP Manila VR  eliminated
# 630                                        AUBG A   advancing
# 631                  Wiseman and the Tribal Chief  eliminated
# 632                            DKW B(aking Bread)   advancing
# 633             IITB Chakraborty &amp; Raghav Raj  eliminated
# 634                                          team      result
# 635                            DKW B(aking Bread)   advancing
# 636                                        AUBG A  eliminated
# 637             Djorđa Kratovca 65/8 parking spot  eliminated
# 638                                   Potsdam A-Z  eliminated
# 639                                          team      result
# 640       UWODS Revealed Preference for Suffering   advancing
# 641            GUU (C)an you spot the difference?  eliminated
# 642                      DU raam bharose aaye hai  eliminated
# 643  Aberdeen Don&#x27;t ask us about the balkans  eliminated
#
#              categories                                                 R1  \
# 624  Closing Opposition  ilijaⒸ , Ellie Middleton , Emma Walker , Harve...
# 625                side                                       adjudicators
# 626  Opening Government  Maša PopeskovićⒸ , Aaryav Bansal , Lwandle Nts...
# 627  Opening Opposition  Maša PopeskovićⒸ , Aaryav Bansal , Lwandle Nts...
# 628  Closing Government  Maša PopeskovićⒸ , Aaryav Bansal , Lwandle Nts...
# 629  Closing Opposition  Maša PopeskovićⒸ , Aaryav Bansal , Lwandle Nts...
# 630  Opening Government    Henry Clement-JonesⒸ , Martin Lim , Ryna Saxena
# 631  Opening Opposition    Henry Clement-JonesⒸ , Martin Lim , Ryna Saxena
# 632  Closing Government    Henry Clement-JonesⒸ , Martin Lim , Ryna Saxena
# 633  Closing Opposition    Henry Clement-JonesⒸ , Martin Lim , Ryna Saxena
# 634                side                                       adjudicators
# 635  Opening Government  William SmithⒸ , Jim Balatos , John Washburn ,...
# 636  Opening Opposition  William SmithⒸ , Jim Balatos , John Washburn ,...
# 637  Closing Government  William SmithⒸ , Jim Balatos , John Washburn ,...
# 638  Closing Opposition  William SmithⒸ , Jim Balatos , John Washburn ,...
# 639                side                                       adjudicators
# 640  Opening Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 641  Opening Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 642  Closing Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 643  Closing Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#      Round
# 624      9
# 625     10
# 626     10
# 627     10
# 628     10
# 629     10
# 630     10
# 631     10
# 632     10
# 633     10
# 634     11
# 635     11
# 636     11
# 637     11
# 638     11
# 639     12
# 640     12
# 641     12
# 642     12
# 643     12

# %%
df7 = df4
df7['Speaker1'], df7['Speaker2'],df7['Speaker1_score'], df7['Speaker2_score'], df7['Comp_name'] = 0,0,0,0,comp_name
for i in df7.index:
    #print(df7.Rk[i])
    loop_speaker1 = 'iron/swing'
    loop_speaker2 = 'iron/swing'
    loop_speaker1_score = 0
    loop_speaker2_score = 0
    loop_round = df7.Round[i]
    for j in speakertab.index:
        if df7.Rk[i] == speakertab.team[j]:
            if loop_speaker1 == 'iron/swing':
                loop_speaker1 = speakertab.speaker[j]
                if df7.team[i] == '1st' or df7.team[i] == '2nd' or df7.team[i] == '3rd' or df7.team[i] == '4th':
                    loop_speaker1_score = speakertab.iat[j,3+loop_round]
                else:
                    loop_speaker1_score = 'outround'
            else:
                loop_speaker2 = speakertab.speaker[j]
                if df7.team[i] == '1st' or df7.team[i] == '2nd' or df7.team[i] == '3rd' or df7.team[i] == '4th':
                    loop_speaker2_score = speakertab.iat[j,3+loop_round]
                else:
                    loop_speaker2_score = 'outround'
    df7.Speaker1[i] = loop_speaker1
    df7.Speaker2[i] = loop_speaker2
    df7.Speaker1_score[i] = loop_speaker1_score
    df7.Speaker2_score[i] = loop_speaker2_score
df7
# Out:
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['Speaker1'], df7['Speaker2'],df7['Speaker1_score'], df7['Speaker2_score'], df7['Comp_name'] = 0,0,0,0,comp_name
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['Speaker1'], df7['Speaker2'],df7['Speaker1_score'], df7['Speaker2_score'], df7['Comp_name'] = 0,0,0,0,comp_name
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['Speaker1'], df7['Speaker2'],df7['Speaker1_score'], df7['Speaker2_score'], df7['Comp_name'] = 0,0,0,0,comp_name
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['Speaker1'], df7['Speaker2'],df7['Speaker1_score'], df7['Speaker2_score'], df7['Comp_name'] = 0,0,0,0,comp_name
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7['Speaker1'], df7['Speaker2'],df7['Speaker1_score'], df7['Speaker2_score'], df7['Comp_name'] = 0,0,0,0,comp_name
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7.Speaker1[i] = loop_speaker1
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7.Speaker2[i] = loop_speaker2
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7.Speaker1_score[i] = loop_speaker1_score
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\973372616.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df7.Speaker2_score[i] = loop_speaker2_score
#                                                Rk        team  \
# 0                                            team      result
# 1                                           LSE C         2nd
# 2          LSE When did Aniket get so big and str         1st
# 3                                  SoBo Crusaders         4th
# 4              4 am start :smile: 3 am start :cry         3rd
# ..                                            ...         ...
# 639                                          team      result
# 640       UWODS Revealed Preference for Suffering   advancing
# 641            GUU (C)an you spot the difference?  eliminated
# 642                      DU raam bharose aaye hai  eliminated
# 643  Aberdeen Don&#x27;t ask us about the balkans  eliminated
#
#              categories                                                 R1  \
# 0                  side                                             ballot
# 1    Opening Government                 Maša PopeskovićⒸ , Matheus Furtado
# 2    Opening Opposition                 Maša PopeskovićⒸ , Matheus Furtado
# 3    Closing Government                 Maša PopeskovićⒸ , Matheus Furtado
# 4    Closing Opposition                 Maša PopeskovićⒸ , Matheus Furtado
# ..                  ...                                                ...
# 639                side                                       adjudicators
# 640  Opening Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 641  Opening Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 642  Closing Government  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 643  Closing Opposition  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#      Round         Speaker1              Speaker2 Speaker1_score  \
# 0        1       iron/swing            iron/swing              0
# 1        1      Michele Liu       Rayaan Aly Khan             80
# 2        1   Sachin Tissera         Arjun Gunalan             80
# 3        1  Krishaan Doctor            Pramit Rao             72
# 4        1    Nyx Kucharski  Bilguun Tserenbadral             76
# ..     ...              ...                   ...            ...
# 639     12       iron/swing            iron/swing              0
# 640     12       Kevin Chen      Jasmeet Randhawa       outround
# 641     12      Harry Braid           Jamie Ghosh       outround
# 642     12  divyanshi dusad       Bhavisya sharma       outround
# 643     12   Stanley Wilcox       Chloe Stevenson       outround
#
#     Speaker2_score                       Comp_name
# 0                0  Warwick Pre-EUDC 2025 (29 rms)
# 1               78  Warwick Pre-EUDC 2025 (29 rms)
# 2               80  Warwick Pre-EUDC 2025 (29 rms)
# 3               72  Warwick Pre-EUDC 2025 (29 rms)
# 4               73  Warwick Pre-EUDC 2025 (29 rms)
# ..             ...                             ...
# 639              0  Warwick Pre-EUDC 2025 (29 rms)
# 640       outround  Warwick Pre-EUDC 2025 (29 rms)
# 641       outround  Warwick Pre-EUDC 2025 (29 rms)
# 642       outround  Warwick Pre-EUDC 2025 (29 rms)
# 643       outround  Warwick Pre-EUDC 2025 (29 rms)
#
# [644 rows x 10 columns]

# %% [markdown]
# ## IV. Grouping the teambased result data up to debate based result data

# %%
df8 = df7
df8

grouped = df8.groupby(['Round', 'R1']).agg(list).reset_index()

# Flatten the grouped DataFrame by splitting the lists into separate columns
# Here, we use the `apply(pd.Series)` to convert each list into a separate column
grouped_expanded = pd.concat([grouped[['Round', 'R1']], 
                              grouped['Rk'].apply(pd.Series), 
                              grouped['categories'].apply(pd.Series), 
                              grouped['team'].apply(pd.Series),
                              grouped['Speaker1'].apply(pd.Series),
                              grouped['Speaker2'].apply(pd.Series),
                              grouped['Speaker1_score'].apply(pd.Series),
                              grouped['Speaker2_score'].apply(pd.Series)], axis=1)

# Rename the columns to match the desired output

# %%
grouped_expanded.columns = ['Round', 'Panel', 
                            'Team1', 'Team2', 'Team3', 'Team4',
                            'Team1 position', 'Team2 position', 'Team3 position', 'Team4 position',
                            'Team1 result', 'Team2 result', 'Team3 result', 'Team4 result',
                            'T1_S1 name', 'T2_S1 name', 'T3_S1 name', 'T4_S1 name',
                            'T1_S2 name', 'T2_S2 name', 'T3_S2 name', 'T4_S2 name',
                            'T1_S1 score', 'T2_S1 score', 'T3_S1 score', 'T4_S1 score',
                            'T1_S2 score', 'T2_S2 score', 'T3_S2 score', 'T4_S2 score']

# %%
grouped_expanded
# Out:
#      Round                                              Panel  \
# 0        1                                       Alex MartinⒸ
# 1        1           AmitaiⒸ , Maja Patynowska , Jim BalatosⓉ
# 2        1  Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...
# 3        1            Ellie MiddletonⒸ , Azwad Abdullah AyanⓉ
# 4        1                                       Emma WalkerⒸ
# ..     ...                                                ...
# 165     10                                       adjudicators
# 166     11  William SmithⒸ , Jim Balatos , John Washburn ,...
# 167     11                                       adjudicators
# 168     12  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 169     12                                       adjudicators
#
#                                        Team1  \
# 0                         ANU Guangzhou Mama
# 1                          DM Hella Adorable
# 2                            Kimbhut Kimakar
# 3                UCL Rick and Morty Season 2
# 4                             Chen &amp; Qiu
# ..                                       ...
# 165                                     team
# 166                       DKW B(aking Bread)
# 167                                     team
# 168  UWODS Revealed Preference for Suffering
# 169                                     team
#
#                                    Team2  \
# 0     A fossil was coaxed out of retirem
# 1                                 AUBG A
# 2         KU Mandatory military dropouts
# 3                            SPSU SPbU A
# 4    Our Opening is Weak but We Finish S
# ..                                   ...
# 165                                  NaN
# 166                               AUBG A
# 167                                  NaN
# 168   GUU (C)an you spot the difference?
# 169                                  NaN
#
#                                           Team3  \
# 0          HH political overreach into my pants
# 1                Edinburgh where&#x27;s wurdaan
# 2    Warwick This House Would Break (But Not Up
# 3            GUU (C)an you spot the difference?
# 4                             THUJ HUJI M&amp;S
# ..                                          ...
# 165                                         NaN
# 166           Djorđa Kratovca 65/8 parking spot
# 167                                         NaN
# 168                    DU raam bharose aaye hai
# 169                                         NaN
#
#                                                  Team4      Team1 position  \
# 0    Chicago That&#x27;s GBP, the price go up if it...  Opening Government
# 1                 E ne le jarabi l&#x27;i la, too much  Opening Government
# 2                   Why does Hilary have an Australian  Opening Government
# 3                                  This debate? Gnarly  Opening Government
# 4                     PUCP Ezeta &amp; Nuñez del Prado  Opening Government
# ..                                                 ...                 ...
# 165                                                NaN                side
# 166                                        Potsdam A-Z  Opening Government
# 167                                                NaN                side
# 168       Aberdeen Don&#x27;t ask us about the balkans  Opening Government
# 169                                                NaN                side
#
#          Team2 position      Team3 position      Team4 position  ...  \
# 0    Opening Opposition  Closing Government  Closing Opposition  ...
# 1    Opening Opposition  Closing Government  Closing Opposition  ...
# 2    Opening Opposition  Closing Government  Closing Opposition  ...
# 3    Opening Opposition  Closing Government  Closing Opposition  ...
# 4    Opening Opposition  Closing Government  Closing Opposition  ...
# ..                  ...                 ...                 ...  ...
# 165                 NaN                 NaN                 NaN  ...
# 166  Opening Opposition  Closing Government  Closing Opposition  ...
# 167                 NaN                 NaN                 NaN  ...
# 168  Opening Opposition  Closing Government  Closing Opposition  ...
# 169                 NaN                 NaN                 NaN  ...
#
#           T3_S2 name                     T4_S2 name T1_S1 score T2_S1 score  \
# 0        Felix Zhang              Victoria Kurakata          81          76
# 1     Wurdaan Kashif                   Nimai Koneru          80          79
# 2          Toby Ford                Henrietta Vanni          76          80
# 3        Jamie Ghosh                         Summer          81          76
# 4    Michael Khalfin  Diego Nuñez del Prado Velarde          79          74
# ..               ...                            ...         ...         ...
# 165              NaN                            NaN         0.0         NaN
# 166   Katarina Lazić              Juliette Scheuing    outround    outround
# 167              NaN                            NaN         0.0         NaN
# 168  Bhavisya sharma                Chloe Stevenson    outround    outround
# 169              NaN                            NaN         0.0         NaN
#
#     T3_S1 score T4_S1 score T1_S2 score T2_S2 score T3_S2 score T4_S2 score
# 0            78          79          81          76          76          80
# 1            80          80          80          77           —          82
# 2            77          81          76          79          77          80
# 3            74          73          81          75          74          73
# 4            75          76          79          72          74          75
# ..          ...         ...         ...         ...         ...         ...
# 165         NaN         NaN         0.0         NaN         NaN         NaN
# 166    outround    outround    outround    outround    outround    outround
# 167         NaN         NaN         0.0         NaN         NaN         NaN
# 168    outround    outround    outround    outround    outround    outround
# 169         NaN         NaN         0.0         NaN         NaN         NaN
#
# [170 rows x 30 columns]

# %%
df9 = grouped_expanded
df9
# Out:
#      Round                                              Panel  \
# 0        1                                       Alex MartinⒸ
# 1        1           AmitaiⒸ , Maja Patynowska , Jim BalatosⓉ
# 2        1  Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...
# 3        1            Ellie MiddletonⒸ , Azwad Abdullah AyanⓉ
# 4        1                                       Emma WalkerⒸ
# ..     ...                                                ...
# 165     10                                       adjudicators
# 166     11  William SmithⒸ , Jim Balatos , John Washburn ,...
# 167     11                                       adjudicators
# 168     12  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
# 169     12                                       adjudicators
#
#                                        Team1  \
# 0                         ANU Guangzhou Mama
# 1                          DM Hella Adorable
# 2                            Kimbhut Kimakar
# 3                UCL Rick and Morty Season 2
# 4                             Chen &amp; Qiu
# ..                                       ...
# 165                                     team
# 166                       DKW B(aking Bread)
# 167                                     team
# 168  UWODS Revealed Preference for Suffering
# 169                                     team
#
#                                    Team2  \
# 0     A fossil was coaxed out of retirem
# 1                                 AUBG A
# 2         KU Mandatory military dropouts
# 3                            SPSU SPbU A
# 4    Our Opening is Weak but We Finish S
# ..                                   ...
# 165                                  NaN
# 166                               AUBG A
# 167                                  NaN
# 168   GUU (C)an you spot the difference?
# 169                                  NaN
#
#                                           Team3  \
# 0          HH political overreach into my pants
# 1                Edinburgh where&#x27;s wurdaan
# 2    Warwick This House Would Break (But Not Up
# 3            GUU (C)an you spot the difference?
# 4                             THUJ HUJI M&amp;S
# ..                                          ...
# 165                                         NaN
# 166           Djorđa Kratovca 65/8 parking spot
# 167                                         NaN
# 168                    DU raam bharose aaye hai
# 169                                         NaN
#
#                                                  Team4      Team1 position  \
# 0    Chicago That&#x27;s GBP, the price go up if it...  Opening Government
# 1                 E ne le jarabi l&#x27;i la, too much  Opening Government
# 2                   Why does Hilary have an Australian  Opening Government
# 3                                  This debate? Gnarly  Opening Government
# 4                     PUCP Ezeta &amp; Nuñez del Prado  Opening Government
# ..                                                 ...                 ...
# 165                                                NaN                side
# 166                                        Potsdam A-Z  Opening Government
# 167                                                NaN                side
# 168       Aberdeen Don&#x27;t ask us about the balkans  Opening Government
# 169                                                NaN                side
#
#          Team2 position      Team3 position      Team4 position  ...  \
# 0    Opening Opposition  Closing Government  Closing Opposition  ...
# 1    Opening Opposition  Closing Government  Closing Opposition  ...
# 2    Opening Opposition  Closing Government  Closing Opposition  ...
# 3    Opening Opposition  Closing Government  Closing Opposition  ...
# 4    Opening Opposition  Closing Government  Closing Opposition  ...
# ..                  ...                 ...                 ...  ...
# 165                 NaN                 NaN                 NaN  ...
# 166  Opening Opposition  Closing Government  Closing Opposition  ...
# 167                 NaN                 NaN                 NaN  ...
# 168  Opening Opposition  Closing Government  Closing Opposition  ...
# 169                 NaN                 NaN                 NaN  ...
#
#           T3_S2 name                     T4_S2 name T1_S1 score T2_S1 score  \
# 0        Felix Zhang              Victoria Kurakata          81          76
# 1     Wurdaan Kashif                   Nimai Koneru          80          79
# 2          Toby Ford                Henrietta Vanni          76          80
# 3        Jamie Ghosh                         Summer          81          76
# 4    Michael Khalfin  Diego Nuñez del Prado Velarde          79          74
# ..               ...                            ...         ...         ...
# 165              NaN                            NaN         0.0         NaN
# 166   Katarina Lazić              Juliette Scheuing    outround    outround
# 167              NaN                            NaN         0.0         NaN
# 168  Bhavisya sharma                Chloe Stevenson    outround    outround
# 169              NaN                            NaN         0.0         NaN
#
#     T3_S1 score T4_S1 score T1_S2 score T2_S2 score T3_S2 score T4_S2 score
# 0            78          79          81          76          76          80
# 1            80          80          80          77           —          82
# 2            77          81          76          79          77          80
# 3            74          73          81          75          74          73
# 4            75          76          79          72          74          75
# ..          ...         ...         ...         ...         ...         ...
# 165         NaN         NaN         0.0         NaN         NaN         NaN
# 166    outround    outround    outround    outround    outround    outround
# 167         NaN         NaN         0.0         NaN         NaN         NaN
# 168    outround    outround    outround    outround    outround    outround
# 169         NaN         NaN         0.0         NaN         NaN         NaN
#
# [170 rows x 30 columns]

# %%
df9 = df9.drop(df9[df9['Team1'] == 'team'].index)
df9 = df9.reset_index()
df9 = df9.drop('index', axis=1)
df9
# Out:
#      Round                                              Panel  \
# 0        1                                       Alex MartinⒸ
# 1        1           AmitaiⒸ , Maja Patynowska , Jim BalatosⓉ
# 2        1  Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...
# 3        1            Ellie MiddletonⒸ , Azwad Abdullah AyanⓉ
# 4        1                                       Emma WalkerⒸ
# ..     ...                                                ...
# 153      9  ilijaⒸ , Ellie Middleton , Emma Walker , Harve...
# 154     10    Henry Clement-JonesⒸ , Martin Lim , Ryna Saxena
# 155     10  Maša PopeskovićⒸ , Aaryav Bansal , Lwandle Nts...
# 156     11  William SmithⒸ , Jim Balatos , John Washburn ,...
# 157     12  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#                                        Team1  \
# 0                         ANU Guangzhou Mama
# 1                          DM Hella Adorable
# 2                            Kimbhut Kimakar
# 3                UCL Rick and Morty Season 2
# 4                             Chen &amp; Qiu
# ..                                       ...
# 153   LSE When did Aniket get so big and str
# 154                                   AUBG A
# 155                              Potsdam A-Z
# 156                       DKW B(aking Bread)
# 157  UWODS Revealed Preference for Suffering
#
#                                    Team2  \
# 0     A fossil was coaxed out of retirem
# 1                                 AUBG A
# 2         KU Mandatory military dropouts
# 3                            SPSU SPbU A
# 4    Our Opening is Weak but We Finish S
# ..                                   ...
# 153   quarter life crisis brought us bac
# 154         Wiseman and the Tribal Chief
# 155    Djorđa Kratovca 65/8 parking spot
# 156                               AUBG A
# 157   GUU (C)an you spot the difference?
#
#                                           Team3  \
# 0          HH political overreach into my pants
# 1                Edinburgh where&#x27;s wurdaan
# 2    Warwick This House Would Break (But Not Up
# 3            GUU (C)an you spot the difference?
# 4                             THUJ HUJI M&amp;S
# ..                                          ...
# 153                          ANU Guangzhou Mama
# 154                          DKW B(aking Bread)
# 155                      DKW Vienna (A)mbulance
# 156           Djorđa Kratovca 65/8 parking spot
# 157                    DU raam bharose aaye hai
#
#                                                  Team4      Team1 position  \
# 0    Chicago That&#x27;s GBP, the price go up if it...  Opening Government
# 1                 E ne le jarabi l&#x27;i la, too much  Opening Government
# 2                   Why does Hilary have an Australian  Opening Government
# 3                                  This debate? Gnarly  Opening Government
# 4                     PUCP Ezeta &amp; Nuñez del Prado  Opening Government
# ..                                                 ...                 ...
# 153                                        Cambridge B  Opening Government
# 154                  IITB Chakraborty &amp; Raghav Raj  Opening Government
# 155                                       UP Manila VR  Opening Government
# 156                                        Potsdam A-Z  Opening Government
# 157       Aberdeen Don&#x27;t ask us about the balkans  Opening Government
#
#          Team2 position      Team3 position      Team4 position  ...  \
# 0    Opening Opposition  Closing Government  Closing Opposition  ...
# 1    Opening Opposition  Closing Government  Closing Opposition  ...
# 2    Opening Opposition  Closing Government  Closing Opposition  ...
# 3    Opening Opposition  Closing Government  Closing Opposition  ...
# 4    Opening Opposition  Closing Government  Closing Opposition  ...
# ..                  ...                 ...                 ...  ...
# 153  Opening Opposition  Closing Government  Closing Opposition  ...
# 154  Opening Opposition  Closing Government  Closing Opposition  ...
# 155  Opening Opposition  Closing Government  Closing Opposition  ...
# 156  Opening Opposition  Closing Government  Closing Opposition  ...
# 157  Opening Opposition  Closing Government  Closing Opposition  ...
#
#            T3_S2 name                     T4_S2 name T1_S1 score T2_S1 score  \
# 0         Felix Zhang              Victoria Kurakata          81          76
# 1      Wurdaan Kashif                   Nimai Koneru          80          79
# 2           Toby Ford                Henrietta Vanni          76          80
# 3         Jamie Ghosh                         Summer          81          76
# 4     Michael Khalfin  Diego Nuñez del Prado Velarde          79          74
# ..                ...                            ...         ...         ...
# 153  Elanor Parkinson                  Olivia Arbour    outround    outround
# 154   Mira Eberdorfer            Pranjal Chakraborty    outround    outround
# 155       Anton Gonta                    Raffy Perez    outround    outround
# 156    Katarina Lazić              Juliette Scheuing    outround    outround
# 157   Bhavisya sharma                Chloe Stevenson    outround    outround
#
#     T3_S1 score T4_S1 score T1_S2 score T2_S2 score T3_S2 score T4_S2 score
# 0            78          79          81          76          76          80
# 1            80          80          80          77           —          82
# 2            77          81          76          79          77          80
# 3            74          73          81          75          74          73
# 4            75          76          79          72          74          75
# ..          ...         ...         ...         ...         ...         ...
# 153    outround    outround    outround    outround    outround    outround
# 154    outround    outround    outround    outround    outround    outround
# 155    outround    outround    outround    outround    outround    outround
# 156    outround    outround    outround    outround    outround    outround
# 157    outround    outround    outround    outround    outround    outround
#
# [158 rows x 30 columns]

# %% [markdown]
# ## Part V. Formatting the data before saving

# %%
def get_chair(text):
    return text.split("Ⓒ")[0]

def get_wing1(paneltext):
    parts = paneltext.split(',')
    return parts[1] if len(parts) > 1 else None  # Returns second part if it exists

def get_wing2(paneltext):
    parts = paneltext.split(',')
    if len(parts) > 2:
        value = parts[2]
        return value if 'Ⓣ' not in value else 0
    return 0

def get_trainee1(paneltext):
    parts = paneltext.split(',')
    for part in parts:
        if 'Ⓣ' in part:
            return part
    return 0

def get_trainee2(paneltext):
    parts = [part for part in paneltext.split(',') if 'Ⓣ' in part]
    return parts[1] if len(parts) > 1 else 0

# Define column names
columns = ['Round', 'Panel', 
           'OG', 'OO', 'CG','CO',
           'OG speaker 1', 'OG speaker 2', 'OO speaker 1','OO speaker 2',
           'CG speaker 1', 'CG speaker 2', 'CO speaker 1','CO speaker 2',
           'OG1 score', 'OG2 score', 'OO1 score','OO2 score',
           'CG1 score', 'CG2 score', 'CO1 score','CO2 score',
           'Roundtype', 'Panel_size', 'Voting_panel_size',
           'Chair', 'Wing1', 'Wing2',
           'Trainee1', 'Trainee2', 'Comp_name']

# Get length of df9 
rownumbers = df9.shape[0] 

# Create an empty DataFrame with NaN (or pd.NA) values
data = pd.DataFrame(data={col: [0] * rownumbers for col in columns})

for i in df9.index:
    data.Round[i] = df9.Round[i]
    data.Panel[i] = df9.Panel[i]
    
    lineups = df9.iloc[i,6:10].tolist()
    pos_og = lineups.index('Opening Government')
    pos_oo = lineups.index('Opening Opposition')
    pos_cg = lineups.index('Closing Government')
    pos_co = lineups.index('Closing Opposition')
    teams_order = [pos_og, pos_oo, pos_cg, pos_co]
    
    data.OG[i] = df9.iat[i,teams_order[0]+2]
    data.OO[i] = df9.iat[i,teams_order[1]+2]
    data.CG[i] = df9.iat[i,teams_order[2]+2]
    data.CO[i] = df9.iat[i,teams_order[3]+2]
    
    data.iat[i,6] = df9.iat[i,teams_order[0]+14]
    data.iat[i,7] = df9.iat[i,teams_order[0]+18]
    data.iat[i,8] = df9.iat[i,teams_order[1]+14]
    data.iat[i,9] = df9.iat[i,teams_order[1]+18]
    data.iat[i,10] = df9.iat[i,teams_order[2]+14]
    data.iat[i,11] = df9.iat[i,teams_order[2]+18]
    data.iat[i,12] = df9.iat[i,teams_order[3]+14]
    data.iat[i,13] = df9.iat[i,teams_order[3]+18]
    
    if df9.iat[i,teams_order[0]+22] == 'outround':
        data.iat[i,14] = df9.iat[i,teams_order[0]+10]
        data.iat[i,15] = df9.iat[i,teams_order[0]+10]
        data.iat[i,16] = df9.iat[i,teams_order[1]+10]
        data.iat[i,17] = df9.iat[i,teams_order[1]+10]
        data.iat[i,18] = df9.iat[i,teams_order[2]+10]
        data.iat[i,19] = df9.iat[i,teams_order[2]+10]
        data.iat[i,20] = df9.iat[i,teams_order[3]+10]
        data.iat[i,21] = df9.iat[i,teams_order[3]+10]
        data.Roundtype[i] = "outround"
        
    else:
        data.iat[i,14] = df9.iat[i,teams_order[0]+22]
        data.iat[i,15] = df9.iat[i,teams_order[0]+26]
        data.iat[i,16] = df9.iat[i,teams_order[1]+22]
        data.iat[i,17] = df9.iat[i,teams_order[1]+26]
        data.iat[i,18] = df9.iat[i,teams_order[2]+22]
        data.iat[i,19] = df9.iat[i,teams_order[2]+26]
        data.iat[i,20] = df9.iat[i,teams_order[3]+22]
        data.iat[i,21] = df9.iat[i,teams_order[3]+26]
        data.Roundtype[i] = "inround"
        
    data.Panel_size[i] = df9.Panel[i].count(",")+1
    data.Voting_panel_size[i] = data.Panel_size[i] - df9.Panel[i].count("Ⓣ")
    if df9.Panel[i] != 0:
        data.Chair[i]  = get_chair(df9.Panel[i])
        
    if data.Panel_size[i] > 0:
        data.Wing1[i] = get_wing1(df9.Panel[i])
    if data.Panel_size[i] > 1:
        data.Wing2[i] = get_wing2(df9.Panel[i])
    if data.Panel_size[i] > 0:
        data.Trainee1[i] = get_trainee1(df9.Panel[i])
    if data.Panel_size[i] > 1:
        data.Trainee2[i] = get_trainee2(df9.Panel[i])
        
    data.Comp_name[i] = comp_name
data
# Out:
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.OG[i] = df9.iat[i,teams_order[0]+2]
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.OO[i] = df9.iat[i,teams_order[1]+2]
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.CG[i] = df9.iat[i,teams_order[2]+2]
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.CO[i] = df9.iat[i,teams_order[3]+2]
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Roundtype[i] = "inround"
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Panel_size[i] = df9.Panel[i].count(",")+1
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Voting_panel_size[i] = data.Panel_size[i] - df9.Panel[i].count("Ⓣ")
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Chair[i]  = get_chair(df9.Panel[i])
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Wing1[i] = get_wing1(df9.Panel[i])
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Trainee1[i] = get_trainee1(df9.Panel[i])
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Comp_name[i] = comp_name
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Round[i] = df9.Round[i]
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Panel[i] = df9.Panel[i]
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Wing2[i] = get_wing2(df9.Panel[i])
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Trainee2[i] = get_trainee2(df9.Panel[i])
# C:\Users\andra\AppData\Local\Temp\ipykernel_36628\3157058536.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.Roundtype[i] = "outround"
#      Round                                              Panel  \
# 0        1                                       Alex MartinⒸ
# 1        1           AmitaiⒸ , Maja Patynowska , Jim BalatosⓉ
# 2        1  Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...
# 3        1            Ellie MiddletonⒸ , Azwad Abdullah AyanⓉ
# 4        1                                       Emma WalkerⒸ
# ..     ...                                                ...
# 153      9  ilijaⒸ , Ellie Middleton , Emma Walker , Harve...
# 154     10    Henry Clement-JonesⒸ , Martin Lim , Ryna Saxena
# 155     10  Maša PopeskovićⒸ , Aaryav Bansal , Lwandle Nts...
# 156     11  William SmithⒸ , Jim Balatos , John Washburn ,...
# 157     12  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#                                           OG  \
# 0                         ANU Guangzhou Mama
# 1                          DM Hella Adorable
# 2                            Kimbhut Kimakar
# 3                UCL Rick and Morty Season 2
# 4                             Chen &amp; Qiu
# ..                                       ...
# 153   LSE When did Aniket get so big and str
# 154                                   AUBG A
# 155                              Potsdam A-Z
# 156                       DKW B(aking Bread)
# 157  UWODS Revealed Preference for Suffering
#
#                                       OO  \
# 0     A fossil was coaxed out of retirem
# 1                                 AUBG A
# 2         KU Mandatory military dropouts
# 3                            SPSU SPbU A
# 4    Our Opening is Weak but We Finish S
# ..                                   ...
# 153   quarter life crisis brought us bac
# 154         Wiseman and the Tribal Chief
# 155    Djorđa Kratovca 65/8 parking spot
# 156                               AUBG A
# 157   GUU (C)an you spot the difference?
#
#                                              CG  \
# 0          HH political overreach into my pants
# 1                Edinburgh where&#x27;s wurdaan
# 2    Warwick This House Would Break (But Not Up
# 3            GUU (C)an you spot the difference?
# 4                             THUJ HUJI M&amp;S
# ..                                          ...
# 153                          ANU Guangzhou Mama
# 154                          DKW B(aking Bread)
# 155                      DKW Vienna (A)mbulance
# 156           Djorđa Kratovca 65/8 parking spot
# 157                    DU raam bharose aaye hai
#
#                                                     CO           OG speaker 1  \
# 0    Chicago That&#x27;s GBP, the price go up if it...        Dhruv Hariharan
# 1                 E ne le jarabi l&#x27;i la, too much           Helena Hecke
# 2                   Why does Hilary have an Australian  Syeda Tanzeeha Sajida
# 3                                  This debate? Gnarly             Jack Story
# 4                     PUCP Ezeta &amp; Nuñez del Prado            Raymond Qiu
# ..                                                 ...                    ...
# 153                                        Cambridge B         Sachin Tissera
# 154                  IITB Chakraborty &amp; Raghav Raj          Mihaela Peeva
# 155                                       UP Manila VR       Susanna Wirthgen
# 156                                        Potsdam A-Z        Victor Bervoets
# 157       Aberdeen Don&#x27;t ask us about the balkans             Kevin Chen
#
#           OG speaker 2              OO speaker 1      OO speaker 2  ...  \
# 0     Elanor Parkinson           Linh Đặng-Hoàng      Trimann Johl  ...
# 1          Adora Sabau             Mihaela Peeva  Presian Mihaylov  ...
# 2    Nafis Hasan Ruman             Na’ama Benamy      Seungjae Han  ...
# 3             Rick Tan  Vinogradskaia Anastasiia   Ignatenko Roman  ...
# 4          Claire Chen       Moez Uddin Ashrafee     Faisal Raihan  ...
# ..                 ...                       ...               ...  ...
# 153      Arjun Gunalan             Biser Angelov    Maria Matcheva  ...
# 154   Presian Mihaylov        Henaku Kwasi Owusu    Desmond Dorvlo  ...
# 155  Juliette Scheuing             Novak Čelebić    Katarina Lazić  ...
# 156    Mira Eberdorfer             Mihaela Peeva  Presian Mihaylov  ...
# 157   Jasmeet Randhawa               Harry Braid       Jamie Ghosh  ...
#
#       CO2 score Roundtype Panel_size Voting_panel_size  \
# 0            80   inround          1                 1
# 1            82   inround          3                 2
# 2            80   inround          3                 2
# 3            73   inround          2                 1
# 4            75   inround          1                 1
# ..          ...       ...        ...               ...
# 153  eliminated  outround          7                 7
# 154  eliminated  outround          3                 3
# 155  eliminated  outround          3                 3
# 156  eliminated  outround          5                 5
# 157  eliminated  outround          5                 5
#
#                         Chair                       Wing1  \
# 0                 Alex Martin                         NaN
# 1                      Amitai            Maja Patynowska
# 2    Dominik Bartosz Jasiolek                   Ayushman
# 3             Ellie Middleton        Azwad Abdullah AyanⓉ
# 4                 Emma Walker                        None
# ..                        ...                         ...
# 153                     ilija            Ellie Middleton
# 154       Henry Clement-Jones                 Martin Lim
# 155           Maša Popesković              Aaryav Bansal
# 156             William Smith                Jim Balatos
# 157                Liam Urban   Dominik Bartosz Jasiolek
#
#                    Wing2               Trainee1 Trainee2  \
# 0                      0                      0        0
# 1                      0           Jim BalatosⓉ        0
# 2                      0           Surya AnandⓉ        0
# 3                      0   Azwad Abdullah AyanⓉ        0
# 4                      0                      0        0
# ..                   ...                    ...      ...
# 153         Emma Walker                       0        0
# 154          Ryna Saxena                      0        0
# 155   Lwandle Ntshangase                      0        0
# 156       John Washburn                       0        0
# 157       John Washburn                       0        0
#
#                           Comp_name
# 0    Warwick Pre-EUDC 2025 (29 rms)
# 1    Warwick Pre-EUDC 2025 (29 rms)
# 2    Warwick Pre-EUDC 2025 (29 rms)
# 3    Warwick Pre-EUDC 2025 (29 rms)
# 4    Warwick Pre-EUDC 2025 (29 rms)
# ..                              ...
# 153  Warwick Pre-EUDC 2025 (29 rms)
# 154  Warwick Pre-EUDC 2025 (29 rms)
# 155  Warwick Pre-EUDC 2025 (29 rms)
# 156  Warwick Pre-EUDC 2025 (29 rms)
# 157  Warwick Pre-EUDC 2025 (29 rms)
#
# [158 rows x 31 columns]

# %%
reordered_columns = ['Comp_name', 'Round', 'Chair', 'Roundtype',
           'OG', 'OO', 'CG','CO',
           'OG speaker 1', 'OG speaker 2', 'OO speaker 1','OO speaker 2',
           'CG speaker 1', 'CG speaker 2', 'CO speaker 1','CO speaker 2',
           'OG1 score', 'OG2 score', 'OO1 score','OO2 score',
           'CG1 score', 'CG2 score', 'CO1 score','CO2 score',
           'Panel_size', 'Voting_panel_size', 'Panel',
           'Wing1', 'Wing2', 'Trainee1', 'Trainee2']
data = data[reordered_columns]
data
# Out:
#                           Comp_name  Round                     Chair  \
# 0    Warwick Pre-EUDC 2025 (29 rms)      1               Alex Martin
# 1    Warwick Pre-EUDC 2025 (29 rms)      1                    Amitai
# 2    Warwick Pre-EUDC 2025 (29 rms)      1  Dominik Bartosz Jasiolek
# 3    Warwick Pre-EUDC 2025 (29 rms)      1           Ellie Middleton
# 4    Warwick Pre-EUDC 2025 (29 rms)      1               Emma Walker
# ..                              ...    ...                       ...
# 153  Warwick Pre-EUDC 2025 (29 rms)      9                     ilija
# 154  Warwick Pre-EUDC 2025 (29 rms)     10       Henry Clement-Jones
# 155  Warwick Pre-EUDC 2025 (29 rms)     10           Maša Popesković
# 156  Warwick Pre-EUDC 2025 (29 rms)     11             William Smith
# 157  Warwick Pre-EUDC 2025 (29 rms)     12                Liam Urban
#
#     Roundtype                                       OG  \
# 0     inround                       ANU Guangzhou Mama
# 1     inround                        DM Hella Adorable
# 2     inround                          Kimbhut Kimakar
# 3     inround              UCL Rick and Morty Season 2
# 4     inround                           Chen &amp; Qiu
# ..        ...                                      ...
# 153  outround   LSE When did Aniket get so big and str
# 154  outround                                   AUBG A
# 155  outround                              Potsdam A-Z
# 156  outround                       DKW B(aking Bread)
# 157  outround  UWODS Revealed Preference for Suffering
#
#                                       OO  \
# 0     A fossil was coaxed out of retirem
# 1                                 AUBG A
# 2         KU Mandatory military dropouts
# 3                            SPSU SPbU A
# 4    Our Opening is Weak but We Finish S
# ..                                   ...
# 153   quarter life crisis brought us bac
# 154         Wiseman and the Tribal Chief
# 155    Djorđa Kratovca 65/8 parking spot
# 156                               AUBG A
# 157   GUU (C)an you spot the difference?
#
#                                              CG  \
# 0          HH political overreach into my pants
# 1                Edinburgh where&#x27;s wurdaan
# 2    Warwick This House Would Break (But Not Up
# 3            GUU (C)an you spot the difference?
# 4                             THUJ HUJI M&amp;S
# ..                                          ...
# 153                          ANU Guangzhou Mama
# 154                          DKW B(aking Bread)
# 155                      DKW Vienna (A)mbulance
# 156           Djorđa Kratovca 65/8 parking spot
# 157                    DU raam bharose aaye hai
#
#                                                     CO           OG speaker 1  \
# 0    Chicago That&#x27;s GBP, the price go up if it...        Dhruv Hariharan
# 1                 E ne le jarabi l&#x27;i la, too much           Helena Hecke
# 2                   Why does Hilary have an Australian  Syeda Tanzeeha Sajida
# 3                                  This debate? Gnarly             Jack Story
# 4                     PUCP Ezeta &amp; Nuñez del Prado            Raymond Qiu
# ..                                                 ...                    ...
# 153                                        Cambridge B         Sachin Tissera
# 154                  IITB Chakraborty &amp; Raghav Raj          Mihaela Peeva
# 155                                       UP Manila VR       Susanna Wirthgen
# 156                                        Potsdam A-Z        Victor Bervoets
# 157       Aberdeen Don&#x27;t ask us about the balkans             Kevin Chen
#
#           OG speaker 2  ...   CG2 score   CO1 score   CO2 score Panel_size  \
# 0     Elanor Parkinson  ...          76          79          80          1
# 1          Adora Sabau  ...           —          80          82          3
# 2    Nafis Hasan Ruman  ...          77          81          80          3
# 3             Rick Tan  ...          74          73          73          2
# 4          Claire Chen  ...          74          76          75          1
# ..                 ...  ...         ...         ...         ...        ...
# 153      Arjun Gunalan  ...  eliminated  eliminated  eliminated          7
# 154   Presian Mihaylov  ...   advancing  eliminated  eliminated          3
# 155  Juliette Scheuing  ...  eliminated  eliminated  eliminated          3
# 156    Mira Eberdorfer  ...  eliminated  eliminated  eliminated          5
# 157   Jasmeet Randhawa  ...  eliminated  eliminated  eliminated          5
#
#     Voting_panel_size                                              Panel  \
# 0                   1                                       Alex MartinⒸ
# 1                   2           AmitaiⒸ , Maja Patynowska , Jim BalatosⓉ
# 2                   2  Dominik Bartosz JasiolekⒸ , Ayushman , Surya A...
# 3                   1            Ellie MiddletonⒸ , Azwad Abdullah AyanⓉ
# 4                   1                                       Emma WalkerⒸ
# ..                ...                                                ...
# 153                 7  ilijaⒸ , Ellie Middleton , Emma Walker , Harve...
# 154                 3    Henry Clement-JonesⒸ , Martin Lim , Ryna Saxena
# 155                 3  Maša PopeskovićⒸ , Aaryav Bansal , Lwandle Nts...
# 156                 5  William SmithⒸ , Jim Balatos , John Washburn ,...
# 157                 5  Liam UrbanⒸ , Dominik Bartosz Jasiolek , John ...
#
#                           Wing1                Wing2               Trainee1  \
# 0                           NaN                    0                      0
# 1              Maja Patynowska                     0           Jim BalatosⓉ
# 2                     Ayushman                     0           Surya AnandⓉ
# 3          Azwad Abdullah AyanⓉ                    0   Azwad Abdullah AyanⓉ
# 4                          None                    0                      0
# ..                          ...                  ...                    ...
# 153            Ellie Middleton          Emma Walker                       0
# 154                 Martin Lim           Ryna Saxena                      0
# 155              Aaryav Bansal    Lwandle Ntshangase                      0
# 156                Jim Balatos        John Washburn                       0
# 157   Dominik Bartosz Jasiolek        John Washburn                       0
#
#     Trainee2
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 153        0
# 154        0
# 155        0
# 156        0
# 157        0
#
# [158 rows x 31 columns]

# %%
teamtab.to_excel(comp_name+'_teamtab_done'+'.xlsx', index=True)
speakertab.to_excel(comp_name+'_speakertab_done'+'.xlsx', index=True)
data.to_excel(comp_name+'_rounds_done'+'.xlsx', index=True)
